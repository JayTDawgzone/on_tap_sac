# %%
import pandas as pd
import numpy as np
import pymongo
import dns
import datetime as dt

# %%
coordinates_file = '../data/coordinates.csv'
data_file = '../data/raw_data.xlsx'

# %%
data = pd.read_excel(data_file)
coordinates = pd.read_csv(coordinates_file)

# %%
username = ''
password = ''
conn = 'mongodb+srv://' + username +':' + password + '@cluster0-paegd.mongodb.net/test?retryWrites=true&w=majority'
client = pymongo.MongoClient(conn)
db = client['beer_db']

# %%
data.drop(['ServiceCenter', 'Zone', 'AccNumber', 'SystemName', 'StationName', 'TowerID', 'TowerSortOrder', 'FaucetCount', 'Distributor', 'Technician', 'DayOfService', 'TripTitle','TripCancelReason'], axis=1,inplace=True)

# %%
coordinates.columns.values[0] = "LocationID"

# %%
merge = pd.merge(data, coordinates, how='left', on='LocationID')

# %%
merge.dropna(inplace=True)

# %%
merge['Location'] = merge['Location'].str.replace('.','')
merge['BreweryName'] = merge['BreweryName'].str.replace('.','')
merge['Address'] = merge['Address'].str.replace('.','')
merge['BrandName'] = merge['BrandName'].str.replace('.','')
merge['Location'] = merge['Location'].str.replace('2M - ','')
merge['Location'] = merge['Location'].str.replace('NP - ','')
merge['Location'] = merge['Location'].str.replace('OOB - ','')
merge['Location'] = merge['Location'].str.replace('Duplicate - ','')
merge['Location'] = merge['Location'].str.replace('BO - ','')
merge['Location'] = merge['Location'].str.replace('TC - ','')
merge['Location'] = merge['Location'].str.replace('Seasonal - ','')

# %%
merge.head()
# Out:
#      LocationID                       Location         Address        City  \
# 178        2997  19 Handles (Sacramento/Arden)  4235 Arden Way  Sacramento
# 179        2997  19 Handles (Sacramento/Arden)  4235 Arden Way  Sacramento
# 180        2997  19 Handles (Sacramento/Arden)  4235 Arden Way  Sacramento
# 181        2997  19 Handles (Sacramento/Arden)  4235 Arden Way  Sacramento
# 182        2997  19 Handles (Sacramento/Arden)  4235 Arden Way  Sacramento
#
#          ZIP state                        BrandName               BreweryName  \
# 178  95864.0    CA              Alaskan Hopothermia        Alaskan Brewing Co
# 179  95864.0    CA  Anderson Valley Boont Amber Ale           Anderson Valley
# 180  95864.0    CA                    Angry Orchard            Boston Beer Co
# 181  95864.0    CA        Ballast Point Sculpin IPA      Constellation Brands
# 182  95864.0    CA      Bear Republic Thru The Haze  Bear Republic Brewing Co
#
#      Active Recurring Trip  Service Location - Description  \
# 178                      1   19 Handles (Sacramento/Arden)
# 179                      1   19 Handles (Sacramento/Arden)
# 180                      1   19 Handles (Sacramento/Arden)
# 181                      1   19 Handles (Sacramento/Arden)
# 182                      1   19 Handles (Sacramento/Arden)
#
#      Service Location - Address Line 1  Service Location - City  \
# 178                     4235 Arden Way               Sacramento
# 179                     4235 Arden Way               Sacramento
# 180                     4235 Arden Way               Sacramento
# 181                     4235 Arden Way               Sacramento
# 182                     4235 Arden Way               Sacramento
#
#       Service Location - Postal Code  Service Location - State   Latitude  \
# 178                          95864.0                        CA  38.595658
# 179                          95864.0                        CA  38.595658
# 180                          95864.0                        CA  38.595658
# 181                          95864.0                        CA  38.595658
# 182                          95864.0                        CA  38.595658
#
#       Longitude
# 178 -121.365601
# 179 -121.365601
# 180 -121.365601
# 181 -121.365601
# 182 -121.365601

# %%
unique_id = merge['LocationID'].unique()

# %%
collection = db['accounts']
date = dt.datetime.now().strftime('%x')


for x in unique_id:
    df = merge[merge['LocationID'] == x]
    obj = {
        'date': str(date),
        'id':int(df['LocationID'].iloc[0]),
        'location':str(df['Location'].iloc[0]),
        'address':str(df['Address'].iloc[0]),
        'city':str(df['City'].iloc[0]),
        'zipcode':int(df['ZIP'].iloc[0]),
        'state':str(df['state'].iloc[0]),
        'lat':float(df[' Latitude'].iloc[0]),
        'lng':float(df[' Longitude'].iloc[0]),
        'taps': []
    }
    for index, row in df.iterrows():
        taps = {row['BreweryName']: row['BrandName']}
        obj['taps'].append(taps)

    id = collection.insert_one(obj).inserted_id

# %%
unique_taps = merge['BrandName'].unique()

# %%
collection = db['taps']
date = dt.datetime.now().strftime('%x')
for x in unique_taps:
    df = merge[merge['BrandName'] == x]
    obj = {
        'date': str(date),
        'tap':str(df['BrandName'].iloc[0]),
        'brewery':str(df['BreweryName'].iloc[0]),
        'locations': []
    }
    unique_locations = df['LocationID'].unique()
    for y in unique_locations:
        tf = df[df['LocationID'] == y]
        
        locations = {
        'id': int(tf['LocationID'].iloc[0]),
        'location':str(tf['Location'].iloc[0]),
        'address':str(tf['Address'].iloc[0]),
        'city':str(tf['City'].iloc[0]),
        'zipcode':int(tf['ZIP'].iloc[0]),
        'state':str(tf['state'].iloc[0]),
        'lat':float(tf[' Latitude'].iloc[0]),
        'lng':float(tf[' Longitude'].iloc[0]),
            
        }
        obj['locations'].append(locations)
    id = collection.insert_one(obj).inserted_id

# %%
post
# Out:
# {'date': Timestamp('2020-03-11 12:28:31.884904'),
#  'taps': [{'tap': 'Alaskan Hopothermia',
#    'brewery': 'Alaskan Brewing Co.',
#    'locations': [{'location': '19 Handles (Sacramento/Arden)',
#      'address': '4235 Arden Way',
#      'city': 95864.0,
#      'state': 'CA',
#      'lat': 38.595658,
#      'lng': -121.365601},
#     {'location': 'Arena Softball (Roseville/Industrial)',
#      'address': '8288 Industrial Ave',
#      'city': 95678.0,
#      'state': 'CA',
#      'lat': 38.78467,
#      'lng': -121.30435},
#     {'location': 'Dolans (Folsom/Blue Ravine)',
#      'address': '199 Blue Ravine Rd',
#      'city': 95630.0,
#      'state': 'CA',
#      'lat': 38.65437,
#      'lng': -121.17851},
#     {'location': 'River City Saloon (Sacramento/2nd)',
#      'address': '916 2Nd St',
#      'city': 95814.0,
#      'state': 'CA',
#      'lat': 38.58364,
#      'lng': -121.5039},
#     {'location': 'Rivers Edge Pub (Marysville/12th)',
#      'address': '1 E 12th St',
#      'city': 95901.0,
#      'state': 'CA',
#      'lat': 39.14895,
#      'lng': -121.58396},
#     {'location': "Steve Cook's Fireside Lanes (Citrus Heights/Auburn)",
#      'address': '7901 Auburn Boulevard',
#      'city': 95610.0,
#      'state': 'CA',
#      'lat': 38.709920000000004,
#      'lng': -121.29133999999999}]},
#   {'tap': 'Anderson Valley Boont Amber Ale',
#    'brewery': 'Anderson Valley',
#    'locations': [{'location': '19 Handles (Sacramento/Arden)',
#      'address': '4235 Arden Way',
#      'city': 95864.0,
#      'state': 'CA',
#      'lat': 38.595658,
#      'lng': -121.365601},
#     {'location': '2M - Burgers & Brew (Davis/3rd)',
#      'address': '403 3rd St',
#      'city': 95616.0,
#      'state': 'CA',
#      'lat': 38.544270000000004,
#      'lng': -121.74343999999999},
#     {'location': '2M - Burgers and Brew (Sacramento/3rd)',
#      'address': '317 3rd Street',
#      'city': 95605.0,
#      'state': 'CA',
#      'lat': 38.588023,
#      'lng': -121.510129},
#     {'location': '2M - De Veres Irish Pub (Davis/E)',
#      'address': '217 E St',
#      'city': 95616.0,
#      'state': 'CA',
#      'lat': 38.54385,
#      'lng': -121.74138},
#     {'location': '2M - Oshima Sushi (Sacramento/Natomas Crossing)',
#      'address': '2071 Natomas Crossing Dr',
#      'city': 95834.0,
#      'state': 'CA',
#      'lat': 38.64085,
#      'lng': -121.50923},
#     {'location': '2M - Station 16 (Sacramento/16th)',
#      'address': '1118 16th Street',
#      'city': 95814.0,
#      'state': 'CA',
#      'lat': 38.57638,
#      'lng': -121.48616000000001},
#     {'location': '2M - The Bank (Sacramento/J)',
#      'address': '629 J St',
#      'city': 95814.0,
#      'state': 'CA',
#      'lat': 38.58155,
#      'lng': -121.4978},
#     {'location': "2M - Uncle Vito's (Sacramento/15th)",
#      'address': '1800 15th Street Suite E',
#      'city': 95814.0,
#      'state': 'CA',
#      'lat': 38.56821,
#      'lng': -121.48528999999999},
#     {'location': '2M - Wallys Sports Bar (Cameron Park/Cameron Park)',
#      'address': '4079 Cameron Park Drive',
#      'city': 95682.0,
#      'state': 'CA',
#      'lat': 38.656983000000004,
#      'lng': -120.96892199999999},
#     {'location': '2M - Wunder Bar (Davis/G)',
#      'address': '228 G St',
#      'city': 95616.0,
#      'state': 'CA',
#      'lat': 38.54448,
#      'lng': -121.73893999999999},
#     {'location': '2M - Yardhouse (Roseville/Roseville)',
#      'address': '1166 Roseville Pkwy',
#      'city': 95678.0,
#      'state': 'CA',
#      'lat': 38.770788,
#      'lng': -121.270995},
#     {'location': '2M - Yardhouse (Sacramento/K)',
#      'address': '405 K St Ste 100',
#      'city': 95814.0,
#      'state': 'CA',
#      'lat': 38.581758,
#      'lng': -121.50178600000001},
#     {'location': "Alonzo's Pizza Depot (Citrus Heights/Sunrise)",
#      'address': '7054 Sunrise Blvd',
#      'city': 95610.0,
#      'state': 'CA',
#      'lat': 38.69482,
#      'lng': -121.27026000000001},
#     {'location': "Art's Craft Beer Palace (Roseville/Foothills)",
#      'address': '3031 Foothills Blvd',
#      'city': 95815.0,
#      'state': 'CA',
#      'lat': 38.744957,
#      'lng': -121.308365},
#     {'location': 'Back Forty Texas BBQ (Roseville/Orlando)',
#      'address': '1201 Orlando Ave',
#      'city': 95661.0,
#      'state': 'CA',
#      'lat': 38.72294,
#      'lng': -121.28886000000001},
#     {'location': 'Bella Bru Cafe Natomas (Sacramento/Natomas)',
#      'address': '4680 Natomas Boulevard 100',
#      'city': 95835.0,
#      'state': 'CA',
#      'lat': 38.65827,
#      'lng': -121.51115},
#     {'location': 'Bistro 33 (Davis/F)',
#      'address': '226 F St',
#      'city': 95616.0,
#      'state': 'CA',
#      'lat': 38.544470000000004,
#      'lng': -121.73987},
#     {'location': 'Burger Hut (Cameron Park/Green Valley)',
#      'address': '3000 Green Valley Rd',
#      'city': 95682.0,
#      'state': 'CA',
#      'lat': 38.69705,
#      'lng': -121.00133999999998},
#     {'location': 'Burger Lounge (Roseville/Roseville)',
#      'address': '1198 Roseville Pkwy Ste 135',
#      'city': 95678.0,
#      'state': 'CA',
#      'lat': 38.76829,
#      'lng': -121.26791000000001},
#     {'location': 'Cafe Bernardo (Davis/D)',
#      'address': '234 D St',
#      'city': 95616.0,
#      'state': 'CA',
#      'lat': 38.544290000000004,
#      'lng': -121.74226000000002},
#     {'location': 'Citizen Vine (Lincoln/Twelve Bridges)',
#      'address': '845 Twelve Bridges Dr.',
#      'city': 95648.0,
#      'state': 'CA',
#      'lat': 38.850190000000005,
#      'lng': -121.28526000000001},
#     {'location': "Common Farm Kitchen - Guinda's Farmers Market (Guinda/Hwy 16)",
#      'address': '7624 Hwy 16',
#      'city': 95637.0,
#      'state': 'CA',
#      'lat': 38.827822,
#      'lng': -122.19179399999999},
#     {'location': 'Davis Beer Shoppe (Davis/G)',
#      'address': '211 G St',
#      'city': 95616.0,
#      'state': 'CA',
#      'lat': 38.543839,
#      'lng': -121.739034},
#     {'location': 'El Dorado Saloon (El Dorado Hills/Embarcadero)',
#      'address': '879 Embarcadero Dr',
#      'city': 95762.0,
#      'state': 'CA',
#      'lat': 38.70917,
#      'lng': -121.08476},
#     {'location': 'Enchanted Forest (Placerville/Main)',
#      'address': '372 Main St',
#      'city': 95667.0,
#      'state': 'CA',
#      'lat': 38.728656,
#      'lng': -120.80156699999999},
#     {'location': 'Extreme Pizza (Davis/Mace)',
#      'address': '417 Mace Blvd',
#      'city': 95618.0,
#      'state': 'CA',
#      'lat': 38.549690000000005,
#      'lng': -121.69606},
#     {'location': 'Flames Restaurant & Taphouse (Auburn/Lincoln)',
#      'address': '13434 Lincoln Way',
#      'city': 95603.0,
#      'state': 'CA',
#      'lat': 38.9246,
#      'lng': -121.05565},
#     {'location': 'Folsom Hotel (Folsom/Sutter)',
#      'address': '703 Sutter Street',
#      'city': 95630.0,
#      'state': 'CA',
#      'lat': 38.67755,
#      'lng': -121.1766},
#     {'location': 'Foothill Beer Temple (Shingle Springs/Motherlode)',
#      'address': '4200 Mother Lode Dr #D',
#      'city': 95682.0,
#      'state': 'CA',
#      'lat': 38.66408,
#      'lng': -120.92983000000001},
#     {'location': 'Fox & Goose (Sacramento/R)',
#      'address': '1001 R St',
#      'city': 95811.0,
#      'state': 'CA',
#      'lat': 38.5715,
#      'lng': -121.49694},
#     {'location': 'Jinju Sushi (Woodland/Pioneer)',
#      'address': '467 Pioneer Ave',
#      'city': 95776.0,
#      'state': 'CA',
#      'lat': 38.67474,
#      'lng': -121.7462},
#     {'location': 'Joe Caribe (Auburn/Lincoln)',
#      'address': '13470 Lincoln Way',
#      'city': 95603.0,
#      'state': 'CA',
#      'lat': 38.9271,
#      'lng': -121.05555},
#     {'location': 'Kathmandu Kitchen (Davis/G)',
#      'address': '234 G St',
#      'city': 95616.0,
#      'state': 'CA',
#      'lat': 38.54459,
#      'lng': -121.73907},
#     {'location': 'Kennys Bar (Woodland/East)',
#      'address': '721 East St',
#      'city': 95776.0,
#      'state': 'CA',
#      'lat': 38.671209999999995,
#      'lng': -121.76516000000001},
#     {'location': 'Little Belgium Deli (Auburn/Lincoln)',
#      'address': '780 Lincoln Way',
#      'city': 95603.0,
#      'state': 'CA',
#      'lat': 38.90105,
#      'lng': -121.0673},
#     {'location': "Maker's Mountain Eatery (Foresthill/Foresthill)",
#      'address': '24601 Foresthill Rd',
#      'city': 95631.0,
#      'state': 'CA',
#      'lat': 39.02065,
#      'lng': -120.81617},
#     {'location': 'Manaao Thai Cuisine (West Sacramento/Harbor Pointe)',
#      'address': '715 Harbor Pointe Pl',
#      'city': 95605.0,
#      'state': 'CA',
#      'lat': 38.59118,
#      'lng': -121.55463},
#     {'location': 'Milestone (El Dorado Hills/Town Center)',
#      'address': '4359 Town Center Blvd Ste 116',
#      'city': 95762.0,
#      'state': 'CA',
#      'lat': 38.65119,
#      'lng': -121.06603},
#     {'location': 'Mojos Lounge (Woodland/1St)',
#      'address': '428 1St St',
#      'city': 95695.0,
#      'state': 'CA',
#      'lat': 38.67668,
#      'lng': -121.77318999999999},
#     {'location': 'Moose Lodge (Rancho Cordova/Coloma)',
#      'address': '10124 Coloma Rd',
#      'city': 95670.0,
#      'state': 'CA',
#      'lat': 38.590070000000004,
#      'lng': -121.30275},
#     {'location': 'Mountain Mikes (El Dorado Hills/Francisco)',
#      'address': '2222 Francisco Dr',
#      'city': 95762.0,
#      'state': 'CA',
#      'lat': 38.70994,
#      'lng': -121.08649},
#     {'location': 'Mountain Mikes (Elk Grove/Elk Grove)',
#      'address': '9320 Elk Grove Blvd',
#      'city': 95624.0,
#      'state': 'CA',
#      'lat': 38.40828,
#      'lng': -121.35208999999999},
#     {'location': 'Mountain Mikes (Elk Grove/Laguna)',
#      'address': '7440 Laguna Blvd',
#      'city': 95758.0,
#      'state': 'CA',
#      'lat': 38.422909999999995,
#      'lng': -121.4156},
#     {'location': 'Open Rice Kitchen (Davis/G)',
#      'address': '204 G St',
#      'city': 95616.0,
#      'state': 'CA',
#      'lat': 38.54394,
#      'lng': -121.73886},
#     {'location': 'Petes Brewhouse (Folsom/Folsom Auburn)',
#      'address': '6608 Folsom-Auburn Road',
#      'city': 95630.0,
#      'state': 'CA',
#      'lat': 38.68611,
#      'lng': -121.1792},
#     {'location': 'Pistol Petes (Auburn/Harrison)',
#      'address': '140 Harrison Ave',
#      'city': 95603.0,
#      'state': 'CA',
#      'lat': 38.901865,
#      'lng': -121.067071},
#     {'location': 'Plainfield Station (Woodland/County Road)',
#      'address': '23944 County Road 98',
#      'city': 95695.0,
#      'state': 'CA',
#      'lat': 38.590920000000004,
#      'lng': -121.80338},
#     {'location': 'Preethi Indian Cuisine (Davis/2nd)',
#      'address': '715 2Nd St',
#      'city': 95616.0,
#      'state': 'CA',
#      'lat': 38.54363,
#      'lng': -121.73935},
#     {'location': 'Relish Burger Bar (El Dorado Hills/White Rock)',
#      'address': '1000 White Rock Blvd',
#      'city': 95762.0,
#      'state': 'CA',
#      'lat': 38.64656,
#      'lng': -121.06723999999998},
#     {'location': 'River City Saloon (Sacramento/2nd)',
#      'address': '916 2Nd St',
#      'city': 95814.0,
#      'state': 'CA',
#      'lat': 38.58364,
#      'lng': -121.5039},
#     {'location': 'Round Table (Roseville/Foothills)',
#      'address': '4010 Foothills Blvd',
#      'city': 95747.0,
#      'state': 'CA',
#      'lat': 38.75387,
#      'lng': -121.31109},
#     {'location': 'Round Table (Roseville/Woodcreek Oaks)',
#      'address': '9055 Woodcreek Oaks Blvd',
#      'city': 95747.0,
#      'state': 'CA',
#      'lat': 38.79467,
#      'lng': -121.33045},
#     {'location': 'Round Table (Sacramento/398 Florin)',
#      'address': '398 Florin Rd',
#      'city': 95831.0,
#      'state': 'CA',
#      'lat': 38.50785,
#      'lng': -121.5419},
#     {'location': 'Slingshots (Shingle Springs/Coach)',
#      'address': '3300 Coach Ln',
#      'city': 95682.0,
#      'state': 'CA',
#      'lat': 38.65773,
#      'lng': -120.97323},
#     {'location': 'Sophias Thai Bar (Davis/E)',
#      'address': '129 E St',
#      'city': 95616.0,
#      'state': 'CA',
#      'lat': 38.54269,
#      'lng': -121.74123},
#     {'location': 'The Cliff House Of Folsom (Folsom/Greenback Lane)',
#      'address': '9900 Greenback Lane',
#      'city': 95630.0,
#      'state': 'CA',
#      'lat': 38.68355,
#      'lng': -121.17764},
#     {'location': 'Uncle Vitos (Davis/2nd)',
#      'address': '524 2Nd St',
#      'city': 95616.0,
#      'state': 'CA',
#      'lat': 38.54307,
#      'lng': -121.74123},
#     {'location': 'Village Pizza & Grill (Davis/G)',
#      'address': '403 G St',
#      'city': 95616.0,
#      'state': 'CA',
#      'lat': 38.54634,
#      'lng': -121.73986000000001},
#     {'location': 'Village Pizza & Pints (Davis/B)',
#      'address': '236 B St',
#      'city': 95616.0,
#      'state': 'CA',
#      'lat': 38.54378,
#      'lng': -121.74453000000001},
#     {'location': 'Wildwood Kitchen & Bar (Sacramento/Pavilions Lane)',
#      'address': '556 Pavilions Lane',
#      'city': 95825.0,
#      'state': 'CA',
#      'lat': 38.574995,
#      'lng': -121.410058},
#     {'location': 'Woodstocks (Davis/G)',
#      'address': '219 G St',
#      'city': 95616.0,
#      'state': 'CA',
#      'lat': 38.54418,
#      'lng': -121.73925},
#     {'location': 'Yolo Fliers Club (Woodland/Rd 94B)',
#      'address': '17980 C Rd 94B',
#      'city': 95695.0,
#      'state': 'CA',
#      'lat': 38.680271999999995,
#      'lng': -121.870263}]},
#   {'tap': 'Angry Orchard',
#    'brewery': 'Boston Beer Co.',
#    'locations': [{'location': '19 Handles (Sacramento/Arden)',
#      'address': '4235 Arden Way',
#      'city': 95864.0,
#      'state': 'CA',
#      'lat': 38.595658,
#      'lng': -121.365601},
#     {'location': '2M - Blue Cue (Sacramento/28th)',
#      'address': '1004 28th St',
#      'city': 95816.0,
#      'state': 'CA',
#      'lat': 38.573640000000005,
#      'lng': -121.46946000000001},
#     {'location': '2M - Brannon Manor (Sacramento/J)',
#      'address': '106 J Street',
#      'city': 95814.0,
#      'state': 'CA',
#      'lat': 38.58325,
#      'lng': -121.50508},
#     {'location': '2M - Buffalo Wild Wings (Sacramento/N Freeway)',
#      'address': '3600 N Freeway Blvd',
#      'city': 95834.0,
#      'state': 'CA',
#      'lat': 38.639421,
#      'lng': -121.497976},
#     {'location': '2M - Top Golf (Roseville/Freedom)',
#      'address': '1700 Freedom Way',
#      'city': 95678.0,
#      'state': 'CA',
#      'lat': 38.791045000000004,
#      'lng': -121.295667},
#     {'location': '500F Pizza x Taphouse (Sacramento/Arden)',
#      'address': '4341 Arden Wy',
#      'city': 95801.0,
#      'state': 'CA',
#      'lat': 38.596506,
#      'lng': -121.36298899999998},
#     {'location': 'BonChon (Sacramento/Ethan)',
#      'address': '1600 Ethan Way Ste 40',
#      'city': 95825.0,
#      'state': 'CA',
#      'lat': 38.59366,
#      'lng': -121.41851000000001},
#     {'location': "Boston's Pizza Restaurant & Sport's Bar (Citrus Heights/Sunrise)",
#      'address': '5511 Sunrise Blvd',
#      'city': 95610.0,
#      'state': 'CA',
#      'lat': 38.66717,
#      'lng': -121.27333},
#     {'location': 'Chasers (Sacramento/Madison)',
#      'address': '5412 Madison Ave',
#      'city': 95841.0,
#      'state': 'CA',
#      'lat': 38.6602,
#      'lng': -121.33849},
#     {'location': 'Regal Delta Shores 14 & Imax (Sacramento/Delta Shores)',
#      'address': '8136 Delta Shores',
#      'city': 95832.0,
#      'state': 'CA',
#      'lat': 38.465204,
#      'lng': -121.49125},
#     {'location': 'Studio Movie Grill (Rocklin/Commons Dr)',
#      'address': '5140 Commons Dr',
#      'city': 95677.0,
#      'state': 'CA',
#      'lat': 38.802199,
#      'lng': -121.208349},
#     {'location': 'Swabbies (Sacramento/Garden)',
#      'address': '5871 Garden Hwy',
#      'city': 95837.0,
#      'state': 'CA',
#      'lat': 38.67411,
#      'lng': -121.62568},
#     {'location': 'Xochimilcos (Sacramento/Auburn)',
#      'address': '4904 Auburn Blvd',
#      'city': 95841.0,
#      'state': 'CA',
#      'lat': 38.65742,
#      'lng': -121.35028999999999},
#     {'location': 'Zebra Club (Sacramento/P)',
#      'address': '1900 P St',
#      'city': 95811.0,
#      'state': 'CA',
#      'lat': 38.57029,
#      'lng': -121.48398}]},
#   {'tap': 'Ballast Point Sculpin IPA',
#    'brewery': 'Constellation Brands',
#    'locations': [{'location': '19 Handles (Sacramento/Arden)',
#      'address': '4235 Arden Way',
#      'city': 95864.0,
#      'state': 'CA',
#      'lat': 38.595658,
#      'lng': -121.365601},
#     {'location': '2M - Yardhouse (Roseville/Roseville)',
#      'address': '1166 Roseville Pkwy',
#      'city': 95678.0,
#      'state': 'CA',
#      'lat': 38.770788,
#      'lng': -121.270995},
#     {'location': 'Applebees (Citrus Heights/Auburn)',
#      'address': '6900 Auburn Boulevard',
#      'city': 95621.0,
#      'state': 'CA',
#      'lat': 38.691319,
#      'lng': -121.29977099999999},
#     {'location': 'Awful Annies (Auburn/Lincoln)',
#      'address': '13460 Lincoln Way',
#      'city': 95603.0,
#      'state': 'CA',
#      'lat': 38.92677,
#      'lng': -121.05556999999999},
#     {'location': "BJ's Brewhouse (Folsom/E Bidwell)",
#      'address': '2730 E Bidwell St',
#      'city': 95630.0,
#      'state': 'CA',
#      'lat': 38.65617,
#      'lng': -121.12422},
#     {'location': 'Brew Masters Deli (Foresthill/Main)',
#      'address': '24340 Main St',
#      'city': 95631.0,
#      'state': 'CA',
#      'lat': 39.01917,
#      'lng': -120.82112},
#     {'location': 'Burger Lounge (Sacramento/K)',
#      'address': '405 K St Ste 230',
#      'city': 95814.0,
#      'state': 'CA',
#      'lat': 38.581758,
#      'lng': -121.50178600000001},
#     {'location': 'Club Pheasant (West Sacramento/Jefferson)',
#      'address': '2525 Jefferson Blvd',
#      'city': 95691.0,
#      'state': 'CA',
#      'lat': 38.55187,
#      'lng': -121.53741000000001},
#     {'location': 'Friends With Benedicts (El Dorado Hills/Francisco)',
#      'address': '2201 Francisco Dr #110',
#      'city': 95762.0,
#      'state': 'CA',
#      'lat': 38.71148,
#      'lng': -121.0854},
#     {'location': 'Hacienda Del Rio Mexican Restaurant (Folsom/Sutter)',
#      'address': '702 Sutter Street',
#      'city': 95630.0,
#      'state': 'CA',
#      'lat': 38.67796,
#      'lng': -121.17698},
#     {'location': "Harry's Lounge (Sacramento/Auburn)",
#      'address': '4557 Auburn Boulevard',
#      'city': 95841.0,
#      'state': 'CA',
#      'lat': 38.6506,
#      'lng': -121.35823},
#     {'location': "Harry's Sport Bar & Grill (Folsom/Iron Point)",
#      'address': '303 Iron Point Rd',
#      'city': 95630.0,
#      'state': 'CA',
#      'lat': 38.641459999999995,
#      'lng': -121.18921999999999},
#     {'location': 'Hilltop Tavern (Sacramento/Folsom)',
#      'address': '4757 Folsom Blvd',
#      'city': 95819.0,
#      'state': 'CA',
#      'lat': 38.56173,
#      'lng': -121.44628},
#     {'location': 'Mangos Burger Bar (Sacramento/K)',
#      'address': '1930 K St',
#      'city': 95811.0,
#      'state': 'CA',
#      'lat': 38.575509999999994,
#      'lng': -121.48063},
#     {'location': 'Mexquite Cocina Restaurant (Folsom/Blue Ravine)',
#      'address': '25095 Blue Ravine Rd',
#      'city': 95630.0,
#      'state': 'CA',
#      'lat': 38.69008,
#      'lng': -121.11928},
#     {'location': 'Mountain Mikes (Gold River/Gold Springs)',
#      'address': '2220 Gold Springs Ct',
#      'city': 95670.0,
#      'state': 'CA',
#      'lat': 38.62189,
#      'lng': -121.26616000000001},
#     {'location': 'Out of Order Arcade (Auburn/Lincoln)',
#      'address': '13320 Lincoln Way',
#      'city': 95603.0,
#      'state': 'CA',
#      'lat': 38.92139,
#      'lng': -121.0567},
#     {'location': 'Round Table (Davis/W Covell)',
#      'address': '1411 W Covell Blvd',
#      'city': 95616.0,
#      'state': 'CA',
#      'lat': 38.56241,
#      'lng': -121.76591},
#     {'location': 'Round Table (Fair Oaks/Madison)',
#      'address': '8822 Madison Ave',
#      'city': 95628.0,
#      'state': 'CA',
#      'lat': 38.66287,
#      'lng': -121.22958999999999},
#     {'location': 'Stoney Inn (Sacramento/Del Paso)',
#      'address': '1320 Del Paso Blvd',
#      'city': 95815.0,
#      'state': 'CA',
#      'lat': 38.604775,
#      'lng': -121.461694},
#     {'location': 'Straw Hat Pizza (Yuba City/Bogue)',
#      'address': '540 Bogue Rd',
#      'city': 95991.0,
#      'state': 'CA',
#      'lat': 39.09964,
#      'lng': -121.61768000000001},
#     {'location': 'Taqueria Girabaldi (Roseville/Fairway Dr)',
#      'address': '10000 Fairway Dr',
#      'city': 95678.0,
#      'state': 'CA',
#      'lat': 38.784690000000005,
#      'lng': -121.27297},
#     {'location': 'The Cliff House Of Folsom (Folsom/Greenback Lane)',
#      'address': '9900 Greenback Lane',
#      'city': 95630.0,
#      'state': 'CA',
#      'lat': 38.68355,
#      'lng': -121.17764},
#     {'location': 'The Happy Viking (Yuba City/Plumas)',
#      'address': '741 Plumas St',
#      'city': 95991.0,
#      'state': 'CA',
#      'lat': 39.1388,
#      'lng': -121.61643000000001},
#     {'location': 'The Thirsty Goat (Woodland/Grand Ave)',
#      'address': '401-415 Grand Ave',
#      'city': 95695.0,
#      'state': 'CA',
#      'lat': 38.677137,
#      'lng': -121.78241299999999}]},
#   {'tap': 'Bear Republic Thru The Haze',
#    'brewery': 'Bear Republic Brewing Co.',
#    'locations': [{'location': '19 Handles (Sacramento/Arden)',
#      'address': '4235 Arden Way',
#      'city': 95864.0,
#      'state': 'CA',
#      'lat': 38.595658,
#      'lng': -121.365601},
#     {'location': "2M - Uncle Vito's (Sacramento/15th)",
#      'address': '1800 15th Street Suite E',
#      'city': 95814.0,
#      'state': 'CA',
#      'lat': 38.56821,
#      'lng': -121.48528999999999},
#     {'location': '3rd & U Cafe (Davis/3rd)',
#      'address': '223 3rd St',
#      'city': 95616.0,
#      'state': 'CA',
#      'lat': 38.54375,
#      'lng': -121.74631000000001},
#     {'location': 'Elixir (Sacramento/10th)',
#      'address': '1815 10Th St',
#      'city': 95814.0,
#      'state': 'CA',
#      'lat': 38.580921000000004,
#      'lng': -121.493202},
#     {'location': 'Firefly Lounge (Sacramento/Fulton)',
#      'address': '1443 Fulton Avenue',
#      'city': 95864.0,
#      'state': 'CA',
#      'lat': 38.592254,
#      'lng': -121.402293},
#     {'location': 'Formaggio Taverna (Inside Marriott) (Rancho Cordova/Point East)',
#      'address': '11211 Point East Drive',
#      'city': 95742.0,
#      'state': 'CA',
#      'lat': 38.60765,
#      'lng': -121.26918},
#     {'location': 'Pizza Rock (Sacramento/K)',
#      'address': '1020 K St',
#      'city': 95814.0,
#      'state': 'CA',
#      'lat': 38.579085,
#      'lng': -121.493693},
#     {'location': 'Round Table (Sacramento/Watt)',
#      'address': '3327 Watt Ave',
#      'city': 95821.0,
#      'state': 'CA',
#      'lat': 38.627377,
#      'lng': -121.383117},
#     {'location': 'Taste Of Tuscany (Sacramento/Roseville)',
#      'address': '7753 Roseville Rd',
#      'city': 95842.0,
#      'state': 'CA',
#      'lat': 38.706509999999994,
#      'lng': -121.32825},
#     {'location': 'The Bolt (Sacramento/Boxwood)',
#      'address': '2560 Boxwood St',
#      'city': 95815.0,
#      'state': 'CA',
#      'lat': 38.61221,
#      'lng': -121.44611}]},
#   {'tap': 'Bike Dog East X North',
#    'brewery': 'Bike Dog Brewing Co',
#    'locations': [{'location': '19 Handles (Sacramento/Arden)',
#      'address': '4235 Arden Way',
#      'city': 95864.0,
#      'state': 'CA',
#      'lat': 38.595658,
#      'lng': -121.365601},
#     {'location': '2M - SacYard Community Tap House (Sacramento/33rd)',
#      'address': '1725 33rd St',
#      'city': 95816.0,
#      'state': 'CA',
#      'lat': 38.56428,
#      'lng': -121.46573000000001},
#     {'location': 'Gander Taphouse (Loomis/Taylor)',
#      'address': '3550 Taylor Rd',
#      'city': 95650.0,
#      'state': 'CA',
#      'lat': 38.82326,
#      'lng': -121.19238999999999}]},
#   {'tap': 'DESCHUTES BLACK BUTTE PORTER NITRO',
#    'brewery': 'Deschutes Brewery',
#    'locations': [{'location': '19 Handles (Sacramento/Arden)',
#      'address': '4235 Arden Way',
#      'city': 95864.0,
#      'state': 'CA',
#      'lat': 38.595658,
#      'lng': -121.365601},
#     {'location': '2M - 36 Handles Restaurant and pub (El Dorado Hills/White Rock)',
#      'address': '1010 White Rock Rd',
#      'city': 95762.0,
#      'state': 'CA',
#      'lat': 38.646809999999995,
#      'lng': -121.0665},
#     {'location': '2M - D Street Steakhouse (Davis/D)',
#      'address': '113 D St.',
#      'city': 95616.0,
#      'state': 'CA',
#      'lat': 38.542159999999996,
#      'lng': -121.7421},
#     {'location': '2M - Porters House of Draft (Roseville/Foothill)',
#      'address': '7456 Foothill Dr',
#      'city': 95661.0,
#      'state': 'CA',
#      'lat': 38.771146,
#      'lng': -121.31401000000001},
#     {'location': '2M - SacYard Community Tap House (Sacramento/33rd)',
#      'address': '1725 33rd St',
#      'city': 95816.0,
#      'state': 'CA',
#      'lat': 38.56428,
#      'lng': -121.46573000000001},
#     {'location': '2M - Yardhouse (Roseville/Roseville)',
#      'address': '1166 Roseville Pkwy',
#      'city': 95678.0,
#      'state': 'CA',
#      'lat': 38.770788,
#      'lng': -121.270995},
#     {'location': '2M - Yardhouse (Sacramento/K)',
#      'address': '405 K St Ste 100',
#      'city': 95814.0,
#      'state': 'CA',
#      'lat': 38.581758,
#      'lng': -121.50178600000001},
#     {'location': 'Blast & Brew (Rocklin/Commons)',
#      'address': '5198 Commons Drive',
#      'city': 95677.0,
#      'state': 'CA',
#      'lat': 38.804990999999994,
#      'lng': -121.20571399999999},
#     {'location': 'Brick Oven Pub (Placerville/Ray Lawyer)',
#      'address': '2875 Ray Lawyer Dr',
#      'city': 95667.0,
#      'state': 'CA',
#      'lat': 38.72899,
#      'lng': -120.83573999999999},
#     {'location': 'Chicago Fire (Elk Grove/Laguna)',
#      'address': '1701 Laguna Blvd.',
#      'city': 95758.0,
#      'state': 'CA',
#      'lat': 38.427502000000004,
#      'lng': -121.47068999999999},
#     {'location': 'Churchill Arms (Folsom/E Bidwell)',
#      'address': '649 E Bidwell St',
#      'city': 95630.0,
#      'state': 'CA',
#      'lat': 38.672090000000004,
#      'lng': -121.16301000000001},
#     {'location': 'Cold Springs Golf (Placerville/Clubhouse)',
#      'address': '6500 Clubhouse Dr',
#      'city': 95667.0,
#      'state': 'CA',
#      'lat': 38.743851,
#      'lng': -120.879516},
#     {'location': 'Daikon Korean BBQ (Sacramento/N Freeway)',
#      'address': '3636 N Freeway Blvd',
#      'city': 95834.0,
#      'state': 'CA',
#      'lat': 38.63929,
#      'lng': -121.49866000000002},
#     {'location': 'El Dorado Saloon (El Dorado Hills/Embarcadero)',
#      'address': '879 Embarcadero Dr',
#      'city': 95762.0,
#      'state': 'CA',
#      'lat': 38.70917,
#      'lng': -121.08476},
#     {'location': 'Fats Asian Bistro (Folsom/Iron Point)',
#      'address': '2585 Iron Point Rd',
#      'city': 95630.0,
#      'state': 'CA',
#      'lat': 38.647459999999995,
#      'lng': -121.11587},
#     {'location': 'Garys Place (Grass Valley/Mill)',
#      'address': '158 Mill St',
#      'city': 95945.0,
#      'state': 'CA',
#      'lat': 39.21738,
#      'lng': -121.06316000000001},
#     {'location': 'Highwater (Sacramento/Q)',
#      'address': '1910 Q Street',
#      'city': 95811.0,
#      'state': 'CA',
#      'lat': 38.569105,
#      'lng': -121.483998},
#     {'location': 'Kennys Bar (Woodland/East)',
#      'address': '721 East St',
#      'city': 95776.0,
#      'state': 'CA',
#      'lat': 38.671209999999995,
#      'lng': -121.76516000000001},
#     {'location': 'Liars Bench (Placerville/Main)',
#      'address': '255 Main St',
#      'city': 95667.0,
#      'state': 'CA',
#      'lat': 38.72824,
#      'lng': -120.80283999999999},
#     {'location': 'Lidos Cafe (Carmichael/Fair Oaks)',
#      'address': '7907 Fair Oaks Blvd',
#      'city': 95608.0,
#      'state': 'CA',
#      'lat': 38.637370000000004,
#      'lng': -121.31833999999999},
#     {'location': 'Magnolia House Casino at Sheepherders Inn (Rancho Cordova/Folsom)',
#      'address': '11275 Folsom Blvd',
#      'city': 95742.0,
#      'state': 'CA',
#      'lat': 38.60781,
#      'lng': -121.26615},
#     {'location': 'Mountain Springs Hitch And Post (Gold Run/Magra Rd)',
#      'address': '30870 Magra Rd',
#      'city': 95717.0,
#      'state': 'CA',
#      'lat': 39.174659999999996,
#      'lng': -120.85711},
#     {'location': 'My Thai Kitchen (Roseville/Eureka Rd)',
#      'address': '1465 Eureka Rd',
#      'city': 95661.0,
#      'state': 'CA',
#      'lat': 38.75363,
#      'lng': -121.25208},
#     {'location': 'Neighbors Pizza (Olivehurst/Mcgowan)',
#      'address': '1957 Mcgowan Parkway St',
#      'city': 95961.0,
#      'state': 'CA',
#      'lat': 39.07752,
#      'lng': -121.54432},
#     {'location': 'Northridge Restaurant (Penn Valley/Penn Valley)',
#      'address': '17442 Penn Valley Dr',
#      'city': 95946.0,
#      'state': 'CA',
#      'lat': 39.197251,
#      'lng': -121.177507},
#     {'location': 'Old Spaghetti Factory (Sacramento/Watt)',
#      'address': '1625 Watt Ave',
#      'city': 95864.0,
#      'state': 'CA',
#      'lat': 38.594318,
#      'lng': -121.383159},
#     {'location': 'Orchid Thai (Lincoln/Twelve Bridges)',
#      'address': '835 Twelve Bridges Dr',
#      'city': 95648.0,
#      'state': 'CA',
#      'lat': 38.849909999999994,
#      'lng': -121.28627},
#     {'location': 'Palladio Luxe Cinema (Folsom/Palladio Parkway)',
#      'address': '400 Palladio Parkway',
#      'city': 95630.0,
#      'state': 'CA',
#      'lat': 38.649713,
#      'lng': -121.122126},
#     {'location': 'Petes Brewhouse (Folsom/Folsom Auburn)',
#      'address': '6608 Folsom-Auburn Road',
#      'city': 95630.0,
#      'state': 'CA',
#      'lat': 38.68611,
#      'lng': -121.1792},
#     {'location': 'Pf Changs China Bistro (Roseville/Galleria Blvd)',
#      'address': '1212 Galleria Blvd',
#      'city': 95678.0,
#      'state': 'CA',
#      'lat': 38.77296,
#      'lng': -121.26366000000002},
#     {'location': 'Pho Fresh (Rancho Cordova/Coloma)',
#      'address': '10673 Coloma Rd',
#      'city': 95670.0,
#      'state': 'CA',
#      'lat': 38.61237,
#      'lng': -121.29038},
#     {'location': 'Pizza Express (Auburn/Auburn Folsom)',
#      'address': '650 Auburn Folsom Rd',
#      'city': 95603.0,
#      'state': 'CA',
#      'lat': 38.878890000000006,
#      'lng': -121.08058999999999},
#     {'location': 'Pizza Factory (Colfax/S Auburn)',
#      'address': '555 S Auburn St',
#      'city': 95713.0,
#      'state': 'CA',
#      'lat': 39.0935,
#      'lng': -120.9512},
#     {'location': 'Pjs  Roadhouse (Placerville/Mother Lodge)',
#      'address': '5641 Mother Lodge Dr',
#      'city': 95667.0,
#      'state': 'CA',
#      'lat': 38.67941,
#      'lng': -120.87158000000001},
#     {'location': 'Powell Brothers Steamers Co (Placerville/Main)',
#      'address': '425 Main St',
#      'city': 95667.0,
#      'state': 'CA',
#      'lat': 38.72896,
#      'lng': -120.8011},
#     {'location': 'Primo Pizza Burgers & Brew (Rocklin/Sunset Blvd)',
#      'address': '2600 Sunset Blvd',
#      'city': 95677.0,
#      'state': 'CA',
#      'lat': 38.79204,
#      'lng': -121.26154},
#     {'location': 'Rivers Edge (Sacramento/La Riviera)',
#      'address': '8740 La Riviera Dr',
#      'city': 95826.0,
#      'state': 'CA',
#      'lat': 38.56362,
#      'lng': -121.37966000000002},
#     {'location': 'Shady Coffee & Tea (Roseville/Douglas)',
#      'address': '325 Douglas Blvd',
#      'city': 95678.0,
#      'state': 'CA',
#      'lat': 38.74418,
#      'lng': -121.28746000000001},
#     {'location': 'Solomons Delicatessen (Sacramento/K)',
#      'address': '730 K St',
#      'city': 95814.0,
#      'state': 'CA',
#      'lat': 38.579993,
#      'lng': -121.497175},
#     {'location': 'Steves Pizza (El Dorado Hills/Park)',
#      'address': '3941 Park Dr',
#      'city': 95762.0,
#      'state': 'CA',
#      'lat': 38.65522,
#      'lng': -121.06955},
#     {'location': 'Sullys (Rocklin/Pacific)',
#      'address': '4451 Pacific St',
#      'city': 95677.0,
#      'state': 'CA',
#      'lat': 38.800509999999996,
#      'lng': -121.22438000000001},
#     {'location': 'The Happy Viking (Yuba City/Plumas)',
#      'address': '741 Plumas St',
#      'city': 95991.0,
#      'state': 'CA',
#      'lat': 39.1388,
#      'lng': -121.61643000000001},
#     {'location': 'Village Pizza & Grill (Davis/G)',
#      'address': '403 G St',
#      'city': 95616.0,
#      'state': 'CA',
#      'lat': 38.54634,
#      'lng': -121.73986000000001},
#     {'location': 'Village Pizza & Pints (Davis/B)',
#      'address': '236 B St',
#      'city': 95616.0,
#      'state': 'CA',
#      'lat': 38.54378,
#      'lng': -121.74453000000001},
#     {'location': 'Willow Glen Restaurant (Oregon House/Willow Glen)',
#      'address': '13809 Willow Glen Rd.',
#      'city': 95962.0,
#      'state': 'CA',
#      'lat': 39.362987,
#      'lng': -121.324076},
#     {'location': 'Zinfandel Grille (Sacramento/Fair Oaks)',
#      'address': '2384 Fair Oaks Blvd',
#      'city': 95825.0,
#      'state': 'CA',
#      'lat': 38.57396,
#      'lng': -121.4067}]},
#   {'tap': 'Guinness',
#    'brewery': 'Diageo North American',
#    'locations': [{'location': '19 Handles (Sacramento/Arden)',
#      'address': '4235 Arden Way',
#      'city': 95864.0,
#      'state': 'CA',
#      'lat': 38.595658,
#      'lng': -121.365601},
#     {'location': '2M - Original Petes (Sacramento/Gateway)',
#      'address': '4571 Gateway Park Blvd',
#      'city': 95834.0,
#      'state': 'CA',
#      'lat': 38.655390000000004,
#      'lng': -121.5033},
#     {'location': "Boston's Pizza Restaurant & Sport's Bar (Citrus Heights/Sunrise)",
#      'address': '5511 Sunrise Blvd',
#      'city': 95610.0,
#      'state': 'CA',
#      'lat': 38.66717,
#      'lng': -121.27333},
#     {'location': "CJ's Pizza Bar + Grill (Rocklin/Stanford Ranch)",
#      'address': '3211 Stanford Ranch Rd',
#      'city': 95765.0,
#      'state': 'CA',
#      'lat': 38.81467,
#      'lng': -121.25662},
#     {'location': 'Double Tree (Sacramento/Point West)',
#      'address': '2001 Point West Way',
#      'city': 95815.0,
#      'state': 'CA',
#      'lat': 38.600390000000004,
#      'lng': -121.43307},
#     {'location': 'Elixir (Sacramento/10th)',
#      'address': '1815 10Th St',
#      'city': 95814.0,
#      'state': 'CA',
#      'lat': 38.580921000000004,
#      'lng': -121.493202},
#     {'location': 'Hilltop Tavern (Sacramento/Folsom)',
#      'address': '4757 Folsom Blvd',
#      'city': 95819.0,
#      'state': 'CA',
#      'lat': 38.56173,
#      'lng': -121.44628},
#     {'location': 'Liquid Therapy (Fair Oaks/Madison)',
#      'address': '8121 Madison Ave Ste F4',
#      'city': 95628.0,
#      'state': 'CA',
#      'lat': 38.66486,
#      'lng': -121.26029},
#     {'location': 'Nevada Club (Grass Valley/W Main)',
#      'address': '108 W Main St',
#      'city': 95945.0,
#      'state': 'CA',
#      'lat': 39.21927,
#      'lng': -121.06231000000001},
#     {'location': 'On The Y (Sacramento/Fulton)',
#      'address': '670 Fulton Ave',
#      'city': 95825.0,
#      'state': 'CA',
#      'lat': 38.57711,
#      'lng': -121.40173},
#     {'location': 'Relish Burger Bar (El Dorado Hills/White Rock)',
#      'address': '1000 White Rock Blvd',
#      'city': 95762.0,
#      'state': 'CA',
#      'lat': 38.64656,
#      'lng': -121.06723999999998},
#     {'location': "Scotty's Hideaway (Orangevale/Greenback)",
#      'address': '9353 Greenback Lane',
#      'city': 95662.0,
#      'state': 'CA',
#      'lat': 38.678709999999995,
#      'lng': -121.20492},
#     {'location': "Sean Finnegan's Pub (Sacramento/2nd)",
#      'address': '1030 2Nd St',
#      'city': 95814.0,
#      'state': 'CA',
#      'lat': 38.582516,
#      'lng': -121.50447},
#     {'location': 'Serritellas Italian Restaurant (Carmichael/Fair Oaks)',
#      'address': '6241 Fair Oaks Boulevard Ste D',
#      'city': 95608.0,
#      'state': 'CA',
#      'lat': 38.61487,
#      'lng': -121.33041000000001}]},
#   {'tap': 'Heretic Brewery California Pale Ale',
#    'brewery': 'Heretic Brewing Company',
#    'locations': [{'location': '19 Handles (Sacramento/Arden)',
#      'address': '4235 Arden Way',
#      'city': 95864.0,
#      'state': 'CA',
#      'lat': 38.595658,
#      'lng': -121.365601},
#     {'location': '2M - Porters House of Draft (Roseville/Foothill)',
#      'address': '7456 Foothill Dr',
#      'city': 95661.0,
#      'state': 'CA',
#      'lat': 38.771146,
#      'lng': -121.31401000000001},
#     {'location': 'Beach Hut Deli (Rancho Cordova/Golden Centre)',
#      'address': '2095 Golden Center Ln',
#      'city': 95670.0,
#      'state': 'CA',
#      'lat': 38.62688,
#      'lng': -121.26365},
#     {'location': 'Cherry Island Bar & Grill (Elverta/Elverta)',
#      'address': '2360 Elverta Rd',
#      'city': 95626.0,
#      'state': 'CA',
#      'lat': 38.71363,
#      'lng': -121.40867},
#     {'location': 'Marcos Pizza (West Sacramento/Lake Washington)',
#      'address': '2230 Lake Washington',
#      'city': 95691.0,
#      'state': 'CA',
#      'lat': 38.554852000000004,
#      'lng': -121.54002}]},
#   {'tap': 'Hofbrau Munchen Hefeweizen',
#    'brewery': 'S&H Independent',
#    'locations': [{'location': '19 Handles (Sacramento/Arden)',
#      'address': '4235 Arden Way',
#      'city': 95864.0,
#      'state': 'CA',
#      'lat': 38.595658,
#      'lng': -121.365601},
#     {'location': '2M - Kathrins Biergarten (Rocklin/Granite)',
#      'address': '4810 Granite Dr Ste 1A',
#      'city': 95677.0,
#      'state': 'CA',
#      'lat': 38.79115,
#      'lng': -121.22408999999999},
#     {'location': 'Fire Wings (Fair Oaks/Sunrise)',
#      'address': '5350 Sunrise Blvd',
#      'city': 95628.0,
#      'state': 'CA',
#      'lat': 38.662863,
#      'lng': -121.27196299999999}]},
#   {'tap': 'Knee Deep Courtside',
#    'brewery': 'Knee Deep Brewing Co',
#    'locations': [{'location': '19 Handles (Sacramento/Arden)',
#      'address': '4235 Arden Way',
#      'city': 95864.0,
#      'state': 'CA',
#      'lat': 38.595658,
#      'lng': -121.365601},
#     {'location': '2M - Golden 1 Center (Sacramento/David J Stern)',
#      'address': '500 David J Stern Walk',
#      'city': 95814.0,
#      'state': 'CA',
#      'lat': 38.580884999999995,
#      'lng': -121.500456},
#     {'location': 'Arden Hills Country Club (Sacramento/Arden Hills Country Club)',
#      'address': '1220 Arden Hills Country Club Ln',
#      'city': 95864.0,
#      'state': 'CA',
#      'lat': 38.5879,
#      'lng': -121.35533999999998},
#     {'location': 'Folsom State Slickers (Folsom/Gold Lake)',
#      'address': '705 Gold Lake Dr Ste 200',
#      'city': 95630.0,
#      'state': 'CA',
#      'lat': 38.67759,
#      'lng': -121.17991}]},
#   {'tap': 'North Coast Old Rasputin Stout',
#    'brewery': 'North Coast Brewing Co.',
#    'locations': [{'location': '19 Handles (Sacramento/Arden)',
#      'address': '4235 Arden Way',
#      'city': 95864.0,
#      'state': 'CA',
#      'lat': 38.595658,
#      'lng': -121.365601},
#     {'location': '2M - Brass Tap (Rocklin/Commons)',
#      'address': '5150 Commons Dr Ste 101',
#      'city': 95677.0,
#      'state': 'CA',
#      'lat': 38.80223,
#      'lng': -121.20795600000001},
#     {'location': '2M - Burgers & Brew (Davis/3rd)',
#      'address': '403 3rd St',
#      'city': 95616.0,
#      'state': 'CA',
#      'lat': 38.544270000000004,
#      'lng': -121.74343999999999},
#     {'location': '2M - Burgers & Brew (Sacramento/R)',
#      'address': '1409 R Street 105',
#      'city': 95811.0,
#      'state': 'CA',
#      'lat': 38.570075,
#      'lng': -121.49138899999998},
#     {'location': '2M - Kathrins Biergarten (Rocklin/Granite)',
#      'address': '4810 Granite Dr Ste 1A',
#      'city': 95677.0,
#      'state': 'CA',
#      'lat': 38.79115,
#      'lng': -121.22408999999999},
#     {'location': '2M - Red Rabbit (Sacramento/J)',
#      'address': '2718 J St',
#      'city': 95816.0,
#      'state': 'CA',
#      'lat': 38.5739,
#      'lng': -121.46978},
#     {'location': '2M - Sauced BBQ & Spirits (Sacramento/7th)',
#      'address': '1028 7th Street',
#      'city': 95814.0,
#      'state': 'CA',
#      'lat': 38.580703,
#      'lng': -121.497855},
#     {'location': '2M - Wunder Bar (Davis/G)',
#      'address': '228 G St',
#      'city': 95616.0,
#      'state': 'CA',
#      'lat': 38.54448,
#      'lng': -121.73893999999999},
#     {'location': '2M - Yardhouse (Roseville/Roseville)',
#      'address': '1166 Roseville Pkwy',
#      'city': 95678.0,
#      'state': 'CA',
#      'lat': 38.770788,
#      'lng': -121.270995},
#     {'location': 'Aji Japanese Bistro (El Dorado Hills/Town Center)',
#      'address': '4361 Town Center Blvd Ste 111',
#      'city': 95762.0,
#      'state': 'CA',
#      'lat': 38.6515,
#      'lng': -121.06586999999999},
#     {'location': 'Auburn Community Tap House and Bottle Shop (Auburn/Grass Valley)',
#      'address': '1850 Grass Valley Hwy',
#      'city': 95603.0,
#      'state': 'CA',
#      'lat': 38.92929,
#      'lng': -121.08748999999999},
#     {'location': 'Bella Bru Cafe Natomas (Sacramento/Natomas)',
#      'address': '4680 Natomas Boulevard 100',
#      'city': 95835.0,
#      'state': 'CA',
#      'lat': 38.65827,
#      'lng': -121.51115},
#     {'location': 'Brew Masters Deli (Foresthill/Main)',
#      'address': '24340 Main St',
#      'city': 95631.0,
#      'state': 'CA',
#      'lat': 39.01917,
#      'lng': -120.82112},
#     {'location': 'Corner Pocket Sports Bar (Citrus Heights/Sunrise)',
#      'address': '7777 Sunrise Boulevard 1400',
#      'city': 95610.0,
#      'state': 'CA',
#      'lat': 38.70713,
#      'lng': -121.27285},
#     {'location': 'Dantorels Curtis Park (Sacramento/24th)',
#      'address': '2700 24th St',
#      'city': 95818.0,
#      'state': 'CA',
#      'lat': 38.55516,
#      'lng': -121.48348999999999},
#     {'location': 'Der Biergarten (Sacramento/K)',
#      'address': '2332 K St',
#      'city': 95816.0,
#      'state': 'CA',
#      'lat': 38.574095,
#      'lng': -121.47484299999999},
#     {'location': 'Easy On I (Sacramento/I)',
#      'address': '1725 I St',
#      'city': 95811.0,
#      'state': 'CA',
#      'lat': 38.57868,
#      'lng': -121.48245},
#     {'location': 'Highwater (Sacramento/Q)',
#      'address': '1910 Q Street',
#      'city': 95811.0,
#      'state': 'CA',
#      'lat': 38.569105,
#      'lng': -121.483998},
#     {'location': 'Karma Brew (Sacramento/16th)',
#      'address': '1530 16Th St',
#      'city': 95814.0,
#      'state': 'CA',
#      'lat': 38.57173,
#      'lng': -121.48807},
#     {'location': 'Little Belgium Deli (Auburn/Lincoln)',
#      'address': '780 Lincoln Way',
#      'city': 95603.0,
#      'state': 'CA',
#      'lat': 38.90105,
#      'lng': -121.0673},
#     {'location': 'Tapa The World (Sacramento/J)',
#      'address': '2115 J St',
#      'city': 95816.0,
#      'state': 'CA',
#      'lat': 38.57642,
#      'lng': -121.47781},
#     {'location': 'The Canyon Grill And Alehouse (Folsom/Oak)',
#      'address': '9580 Oak Avenue Pky',
#      'city': 95630.0,
#      'state': 'CA',
#      'lat': 38.6985,
#      'lng': -121.19193},
#     {'location': 'Village Pizza & Pints (Davis/B)',
#      'address': '236 B St',
#      'city': 95616.0,
#      'state': 'CA',
#      'lat': 38.54378,
#      'lng': -121.74453000000001}]},
#   {'tap': 'North Coast Pranqster',
#    'brewery': 'North Coast Brewing Co.',
#    'locations': [{'location': '19 Handles (Sacramento/Arden)',
#      'address': '4235 Arden Way',
#      'city': 95864.0,
#      'state': 'CA',
#      'lat': 38.595658,
#      'lng': -121.365601},
#     {'location': '2M - Burgers & Brew (Sacramento/R)',
#      'address': '1409 R Street 105',
#      'city': 95811.0,
#      'state': 'CA',
#      'lat': 38.570075,
#      'lng': -121.49138899999998},
#     {'location': '2M - Burgers and Brew (Sacramento/3rd)',
#      'address': '317 3rd Street',
#      'city': 95605.0,
#      'state': 'CA',
#      'lat': 38.588023,
#      'lng': -121.510129},
#     {'location': 'Buckhorn Grill (Folsom/Palladio)',
#      'address': '250 Palladio Pkwy Ste 1339',
#      'city': 95630.0,
#      'state': 'CA',
#      'lat': 38.647733,
#      'lng': -121.12012299999999},
#     {'location': 'Davis Beer Shoppe (Davis/G)',
#      'address': '211 G St',
#      'city': 95616.0,
#      'state': 'CA',
#      'lat': 38.543839,
#      'lng': -121.739034},
#     {'location': "Father Paddy's Pub (Woodland/Main)",
#      'address': '435 Main St',
#      'city': 95695.0,
#      'state': 'CA',
#      'lat': 38.67753,
#      'lng': -121.77501000000001},
#     {'location': 'Karma Brew (Sacramento/16th)',
#      'address': '1530 16Th St',
#      'city': 95814.0,
#      'state': 'CA',
#      'lat': 38.57173,
#      'lng': -121.48807},
#     {'location': 'Lamppost Pizza  (Davis/Lake)',
#      'address': '1260 Lake Blvd',
#      'city': 95616.0,
#      'state': 'CA',
#      'lat': 38.553909999999995,
#      'lng': -121.78681999999999}]},
#   {'tap': 'Old Speckled Hen',
#    'brewery': 'Morland Brewery',
#    'locations': [{'location': '19 Handles (Sacramento/Arden)',
#      'address': '4235 Arden Way',
#      'city': 95864.0,
#      'state': 'CA',
#      'lat': 38.595658,
#      'lng': -121.365601}]},
#   {'tap': 'Pilsner Urquell',
#    'brewery': 'MillerCoors LLC',
#    'locations': [{'location': '19 Handles (Sacramento/Arden)',
#      'address': '4235 Arden Way',
#      'city': 95864.0,
#      'state': 'CA',
#      'lat': 38.595658,
#      'lng': -121.365601},
#     {'location': 'La Trattoria Bohemia (Sacramento/J)',
#      'address': '3649 J St',
#      'city': 95816.0,
#      'state': 'CA',
#      'lat': 38.57087,
#      'lng': -121.45747},
#     {'location': 'Village Pizza & Grill (Davis/G)',
#      'address': '403 G St',
#      'city': 95616.0,
#      'state': 'CA',
#      'lat': 38.54634,
#      'lng': -121.73986000000001},
#     {'location': 'Village Pizza & Pints (Davis/B)',
#      'address': '236 B St',
#      'city': 95616.0,
#      'state': 'CA',
#      'lat': 38.54378,
#      'lng': -121.74453000000001}]},
#   {'tap': 'Smithwicks Irish Ale',
#    'brewery': 'Diageo North American',
#    'locations': [{'location': '19 Handles (Sacramento/Arden)',
#      'address': '4235 Arden Way',
#      'city': 95864.0,
#      'state': 'CA',
#      'lat': 38.595658,
#      'lng': -121.365601},
#     {'location': '2M - 36 Handles Restaurant and pub (El Dorado Hills/White Rock)',
#      'address': '1010 White Rock Rd',
#      'city': 95762.0,
#      'state': 'CA',
#      'lat': 38.646809999999995,
#      'lng': -121.0665},
#     {'location': '2M - Brannon Manor (Sacramento/J)',
#      'address': '106 J Street',
#      'city': 95814.0,
#      'state': 'CA',
#      'lat': 38.58325,
#      'lng': -121.50508},
#     {'location': '2M - De Veres Irish Pub (Davis/E)',
#      'address': '217 E St',
#      'city': 95616.0,
#      'state': 'CA',
#      'lat': 38.54385,
#      'lng': -121.74138},
#     {'location': '2M - De Veres Irish Pub (Sacramento/L)',
#      'address': '1521 L St',
#      'city': 95814.0,
#      'state': 'CA',
#      'lat': 38.57665,
#      'lng': -121.48642},
#     {'location': '2M - Fat Rabbit (Folsom/Sutter)',
#      'address': '825 Sutter St',
#      'city': 95630.0,
#      'state': 'CA',
#      'lat': 38.67628,
#      'lng': -121.17888},
#     {'location': 'BLARNEY STONE (Orangeville/Greenback)',
#      'address': '8906 Greenback Ln',
#      'city': 95662.0,
#      'state': 'CA',
#      'lat': 38.677929999999996,
#      'lng': -121.22471000000002},
#     {'location': 'Boxing Donkey (Roseville/Lincoln)',
#      'address': '300 Lincoln St',
#      'city': 95678.0,
#      'state': 'CA',
#      'lat': 38.75132,
#      'lng': -121.28419},
#     {'location': 'Churchill Arms (Folsom/E Bidwell)',
#      'address': '649 E Bidwell St',
#      'city': 95630.0,
#      'state': 'CA',
#      'lat': 38.672090000000004,
#      'lng': -121.16301000000001},
#     {'location': "Father Paddy's Pub (Woodland/Main)",
#      'address': '435 Main St',
#      'city': 95695.0,
#      'state': 'CA',
#      'lat': 38.67753,
#      'lng': -121.77501000000001},
#     {'location': 'Fox & Goose (Sacramento/R)',
#      'address': '1001 R St',
#      'city': 95811.0,
#      'state': 'CA',
#      'lat': 38.5715,
#      'lng': -121.49694},
#     {'location': 'Omalleys (Sacramento/2nd)',
#      'address': '1109 2Nd St',
#      'city': 95814.0,
#      'state': 'CA',
#      'lat': 38.58166,
#      'lng': -121.50471999999999},
#     {'location': 'Seasonal - River Shack (Coloma/Hwy 49)',
#      'address': '7170 Hwy 49',
#      'city': 95613.0,
#      'state': 'CA',
#      'lat': 38.683082,
#      'lng': -120.83801899999999},
#     {'location': 'Streets Of London (West Sacramento/Lake Washington)',
#      'address': '2200 Lake Washington Blvd',
#      'city': 95801.0,
#      'state': 'CA',
#      'lat': 38.553773,
#      'lng': -121.537945}]},
#   {'tap': 'Stella Artois',
#    'brewery': 'Anheuser-Busch InBev Inc.',
#    'locations': [{'location': '19 Handles (Sacramento/Arden)',
#      'address': '4235 Arden Way',
#      'city': 95864.0,
#      'state': 'CA',
#      'lat': 38.595658,
#      'lng': -121.365601},
#     {'location': '2M - Ace of Spades (Sacramento/R)',
#      'address': '1417 R St',
#      'city': 95811.0,
#      'state': 'CA',
#      'lat': 38.56989,
#      'lng': -121.49083999999999},
#     {'location': '2M - Badlands (Sacramento/K)',
#      'address': '2003 K St',
#      'city': 95811.0,
#      'state': 'CA',
#      'lat': 38.575520000000004,
#      'lng': -121.47997},
#     {'location': "2M - BJ's Brewhouse (Roseville/Roseville)",
#      'address': '1200 Roseville Pky',
#      'city': 95678.0,
#      'state': 'CA',
#      'lat': 38.76794,
#      'lng': -121.26505},
#     {'location': "2M - BJ's Brewhouse (Sacramento/N Freeway)",
#      'address': '3531 N Freeway Blvd',
#      'city': 95834.0,
#      'state': 'CA',
#      'lat': 38.64018,
#      'lng': -121.50178000000001},
#     {'location': '2M - Blue Cue (Sacramento/28th)',
#      'address': '1004 28th St',
#      'city': 95816.0,
#      'state': 'CA',
#      'lat': 38.573640000000005,
# ...
#      'address': '1030 2Nd St',
#      'city': 95814.0,
#      'state': 'CA',
#      'lat': 38.582516,
#      'lng': -121.50447}]},
#   {'tap': 'Anchor Christmas Ale',
#    'brewery': 'Anchor Brewing Co.',
#    'locations': [{'location': '2M - Wunder Bar (Davis/G)',
#      'address': '228 G St',
#      'city': 95616.0,
#      'state': 'CA',
#      'lat': 38.54448,
#      'lng': -121.73893999999999}]},
#   {'tap': 'Blue Note Stretchy Pants',
#    'brewery': 'Blue Note Brewing Company',
#    'locations': [{'location': '2M - Wunder Bar (Davis/G)',
#      'address': '228 G St',
#      'city': 95616.0,
#      'state': 'CA',
#      'lat': 38.54448,
#      'lng': -121.73893999999999}]},
#   {'tap': 'Dust Bowl Therapist',
#    'brewery': 'Dust Bowl Brewing Co',
#    'locations': [{'location': '2M - Wunder Bar (Davis/G)',
#      'address': '228 G St',
#      'city': 95616.0,
#      'state': 'CA',
#      'lat': 38.54448,
#      'lng': -121.73893999999999},
#     {'location': 'Back Bistro (Folsom/Palladio)',
#      'address': '230 Palladio Pkwy Ste 1201',
#      'city': 95630.0,
#      'state': 'CA',
#      'lat': 38.6474,
#      'lng': -121.11959499999999},
#     {'location': 'Flaming Grill Cafe (West Sacramento/Harbor)',
#      'address': '1350 Harbor Boulevard',
#      'city': 95691.0,
#      'state': 'CA',
#      'lat': 38.57015,
#      'lng': -121.54956000000001},
#     {'location': 'Mountain Mikes (El Dorado Hills/Francisco)',
#      'address': '2222 Francisco Dr',
#      'city': 95762.0,
#      'state': 'CA',
#      'lat': 38.70994,
#      'lng': -121.08649},
#     {'location': 'Mountain Mikes (Gold River/Gold Springs)',
#      'address': '2220 Gold Springs Ct',
#      'city': 95670.0,
#      'state': 'CA',
#      'lat': 38.62189,
#      'lng': -121.26616000000001},
#     {'location': 'Petes Brewhouse (Yuba City/W Onstott)',
#      'address': '866 W Onstott Rd',
#      'city': 95991.0,
#      'state': 'CA',
#      'lat': 39.13674,
#      'lng': -121.634949}]},
#   {'tap': 'Stiegl Radler',
#    'brewery': 'S&H Independent',
#    'locations': [{'location': '2M - Wunder Bar (Davis/G)',
#      'address': '228 G St',
#      'city': 95616.0,
#      'state': 'CA',
#      'lat': 38.54448,
#      'lng': -121.73893999999999},
#     {'location': '2M - Yardhouse (Roseville/Roseville)',
#      'address': '1166 Roseville Pkwy',
#      'city': 95678.0,
#      'state': 'CA',
#      'lat': 38.770788,
#      'lng': -121.270995}]},
#   {'tap': '10 Barrel Profuse Juice Ipa',
#    'brewery': 'Anheuser-Busch InBev Inc.',
#    'locations': [{'location': '2M - Yardhouse (Roseville/Roseville)',
#      'address': '1166 Roseville Pkwy',
#      'city': 95678.0,
#      'state': 'CA',
#      'lat': 38.770788,
#      'lng': -121.270995},
#     {'location': 'Back Forty Texas (Shingle Springs/Durock)',
#      'address': '3977 Durock Rd',
#      'city': 95682.0,
#      'state': 'CA',
#      'lat': 38.66109,
#      'lng': -120.94168},
#     {'location': "Costanza's (Sacramento/L)",
#      'address': '2107 L St',
#      'city': 95816.0,
#      'state': 'CA',
#      'lat': 38.57412,
#      'lng': -121.47905},
#     {'location': 'Main Street Melters (Placerville/Main)',
#      'address': '589 Main St',
#      'city': 95667.0,
#      'state': 'CA',
#      'lat': 38.72917,
#      'lng': -120.79663000000001},
#     {'location': "Messy's Tacos & Treats (Loomis/Taylor Rd)",
#      'address': '3987 Taylor Rd',
#      'city': 95650.0,
#      'state': 'CA',
#      'lat': 38.81047,
#      'lng': -121.20815},
#     {'location': 'Mountain Mikes (Folsom/Blue Ravine)',
#      'address': '25075 Blue Ravine Rd Suite 150',
#      'city': 95630.0,
#      'state': 'CA',
#      'lat': 38.68954,
#      'lng': -121.12123999999999},
#     {'location': 'Petes Brewhouse (El Dorado Hills/Vine)',
#      'address': '2023 Vine St',
#      'city': 95762.0,
#      'state': 'CA',
#      'lat': 38.65202,
#      'lng': -121.06285},
#     {'location': 'Petes Brewhouse (Folsom/Folsom Auburn)',
#      'address': '6608 Folsom-Auburn Road',
#      'city': 95630.0,
#      'state': 'CA',
#      'lat': 38.68611,
#      'lng': -121.1792},
#     {'location': 'Round Table (Loomis/Horseshoe)',
#      'address': '6111 Horseshoe Bar Rd',
#      'city': 95650.0,
#      'state': 'CA',
#      'lat': 38.8184,
#      'lng': -121.18913},
#     {'location': 'Seasonal - River Shack (Coloma/Hwy 49)',
#      'address': '7170 Hwy 49',
#      'city': 95613.0,
#      'state': 'CA',
#      'lat': 38.683082,
#      'lng': -120.83801899999999},
#     {'location': 'Uncle Vitos (Sacramento/16th)',
#      'address': '1501 16Th Street',
#      'city': 95814.0,
#      'state': 'CA',
#      'lat': 38.57203,
#      'lng': -121.48775}]},
#   {'tap': 'Ace Space Bloody Orange',
#    'brewery': 'Ace Cider',
#    'locations': [{'location': '2M - Yardhouse (Roseville/Roseville)',
#      'address': '1166 Roseville Pkwy',
#      'city': 95678.0,
#      'state': 'CA',
#      'lat': 38.770788,
#      'lng': -121.270995},
#     {'location': 'Beach Hut Deli (Auburn/Bowman)',
#      'address': '13471 Bowman Rd',
#      'city': 95603.0,
#      'state': 'CA',
#      'lat': 38.92688,
#      'lng': -121.05694}]},
#   {'tap': 'Alaskan Alaskan Amber',
#    'brewery': 'Alaskan Brewing Co.',
#    'locations': [{'location': '2M - Yardhouse (Roseville/Roseville)',
#      'address': '1166 Roseville Pkwy',
#      'city': 95678.0,
#      'state': 'CA',
#      'lat': 38.770788,
#      'lng': -121.270995},
#     {'location': 'Bigleys Market / Brass Rail (N San Juan/CA-49)',
#      'address': '29336 Ca-49',
#      'city': 95960.0,
#      'state': 'CA',
#      'lat': 39.369948,
#      'lng': -121.10463600000001},
#     {'location': 'Bob & Bettys One Sixty Club (Auburn/Cleveland)',
#      'address': '160 Cleveland Ave',
#      'city': 95603.0,
#      'state': 'CA',
#      'lat': 38.901309999999995,
#      'lng': -121.06806999999999},
#     {'location': 'Broderick Restaurant (West Sacramento/6th)',
#      'address': '319 6th Street',
#      'city': 95605.0,
#      'state': 'CA',
#      'lat': 38.588397,
#      'lng': -121.51419399999999},
#     {'location': 'Candle Rock Lounge/Pinsetters Inc. (Sacramento/Watt)',
#      'address': '2600 Watt Ave',
#      'city': 95821.0,
#      'state': 'CA',
#      'lat': 38.6124,
#      'lng': -121.38134},
#     {'location': 'Coloma Club (Coloma/Hwy 49)',
#      'address': '7171 Hwy 49',
#      'city': 95613.0,
#      'state': 'CA',
#      'lat': 38.810147,
#      'lng': -120.908943},
#     {'location': 'Creekside Cork & Brew (Somerset/Fairplay Road)',
#      'address': '7915 Fairplay Road',
#      'city': 95684.0,
#      'state': 'CA',
#      'lat': 38.59369,
#      'lng': -120.66003},
#     {'location': 'Dads Kitchen #2 (Fair Oaks/Sunset)',
#      'address': '8928 Sunset Ave',
#      'city': 95628.0,
#      'state': 'CA',
#      'lat': 38.652840000000005,
#      'lng': -121.22433000000001},
#     {'location': 'Der Biergarten (Sacramento/K)',
#      'address': '2332 K St',
#      'city': 95816.0,
#      'state': 'CA',
#      'lat': 38.574095,
#      'lng': -121.47484299999999},
#     {'location': 'Djs Grill & Deli (Folsom/Folsom)',
#      'address': '13000 Folsom Boulevard',
#      'city': 95630.0,
#      'state': 'CA',
#      'lat': 38.64391,
#      'lng': -121.18698},
#     {'location': 'Elks Lodge (Elk Grove/Survey)',
#      'address': '9240 Survey Road',
#      'city': 95624.0,
#      'state': 'CA',
#      'lat': 38.377311999999996,
#      'lng': -121.357025},
#     {'location': 'Elks Lodge (Roseville/Brady)',
#      'address': '3000 Brady Ln',
#      'city': 95747.0,
#      'state': 'CA',
#      'lat': 38.75028,
#      'lng': -121.31324},
#     {'location': 'Hard Rock Casino (Wheatland/Forty Mile)',
#      'address': '3317 Forty Mile Rd',
#      'city': 95692.0,
#      'state': 'CA',
#      'lat': 39.048407,
#      'lng': -121.51501200000001},
#     {'location': 'IOOF - Odd Fellows Lodge (Davis/2nd)',
#      'address': '415 2Nd St',
#      'city': 95616.0,
#      'state': 'CA',
#      'lat': 38.54313,
#      'lng': -121.74268000000001},
#     {'location': 'Knights Of Columbus (Sacramento/Newman Court)',
#      'address': '5961 Newman Court',
#      'city': 95819.0,
#      'state': 'CA',
#      'lat': 38.566677,
#      'lng': -121.429841},
#     {'location': 'Knotty Pines Lanes (Pollock Pines/Sanders)',
#      'address': '2667 Sanders Dr',
#      'city': 95726.0,
#      'state': 'CA',
#      'lat': 38.76032,
#      'lng': -120.59173999999999},
#     {'location': 'Legends At Woodcreek (Roseville/Woodcreek Oaks)',
#      'address': '5880 Woodcreek Oaks Blvd',
#      'city': 95747.0,
#      'state': 'CA',
#      'lat': 38.777103000000004,
#      'lng': -121.33134199999999},
#     {'location': 'Mountain Mikes (Granite Bay/Douglas)',
#      'address': '6811 Douglas Blvd',
#      'city': 95746.0,
#      'state': 'CA',
#      'lat': 38.74393,
#      'lng': -121.17378000000001},
#     {'location': 'Parkwest Casino Cordova (Rancho Cordova/Prospect)',
#      'address': '2801 Prospect Park Dr',
#      'city': 95670.0,
#      'state': 'CA',
#      'lat': 38.59194,
#      'lng': -121.28421000000002},
#     {'location': 'Pizza Factory (Pleasant Valley/Pleasant Valley)',
#      'address': '4570 Pleasant Valley Rd',
#      'city': 95726.0,
#      'state': 'CA',
#      'lat': 38.682499,
#      'lng': -120.663324},
#     {'location': 'Players Pub (Fair Oaks/Fair Oaks)',
#      'address': '9729 Fair Oaks Blvd',
#      'city': 95628.0,
#      'state': 'CA',
#      'lat': 38.63966,
#      'lng': -121.2765},
#     {'location': 'Red Rooster Burgers & Brew (Garden Valley/Garden Valley)',
#      'address': '5032 Garden Valley',
#      'city': 95633.0,
#      'state': 'CA',
#      'lat': 38.850127,
#      'lng': -120.860119},
#     {'location': 'Rosatis Pizza (Roseville/Foothill Blvd)',
#      'address': '5140 Foothill Blvd',
#      'city': 95747.0,
#      'state': 'CA',
#      'lat': 38.76218,
#      'lng': -121.31253000000001},
#     {'location': 'Sierra Grill Smokehouse (Auburn/Grass Valley)',
#      'address': '2515 Grass Valley Hwy',
#      'city': 95603.0,
#      'state': 'CA',
#      'lat': 38.93722,
#      'lng': -121.09563999999999},
#     {'location': 'Slingshots (Shingle Springs/Coach)',
#      'address': '3300 Coach Ln',
#      'city': 95682.0,
#      'state': 'CA',
#      'lat': 38.65773,
#      'lng': -120.97323},
#     {'location': 'Sterling Cafe (Lincoln/Sterling Pkwy)',
#      'address': '820 Sterling Pkwy Ste 10',
#      'city': 95648.0,
#      'state': 'CA',
#      'lat': 38.871199,
#      'lng': -121.29633999999999},
#     {'location': 'Steves Pizza (El Dorado Hills/Park)',
#      'address': '3941 Park Dr',
#      'city': 95762.0,
#      'state': 'CA',
#      'lat': 38.65522,
#      'lng': -121.06955},
#     {'location': 'Swabbies (Sacramento/Garden)',
#      'address': '5871 Garden Hwy',
#      'city': 95837.0,
#      'state': 'CA',
#      'lat': 38.67411,
#      'lng': -121.62568},
#     {'location': 'The Couch (Citrus Heights/Madison)',
#      'address': '7431 Madison Ave',
#      'city': 95610.0,
#      'state': 'CA',
#      'lat': 38.663804,
#      'lng': -121.29122199999999},
#     {'location': 'Uncle Vitos (Sacramento/16th)',
#      'address': '1501 16Th Street',
#      'city': 95814.0,
#      'state': 'CA',
#      'lat': 38.57203,
#      'lng': -121.48775},
#     {'location': 'VFW (Folsom/Forrest)',
#      'address': '1300 Forrest St',
#      'city': 95630.0,
#      'state': 'CA',
#      'lat': 38.67399,
#      'lng': -121.18457},
#     {'location': 'Yummy Poke (Rocklin/Lonetree)',
#      'address': '6696 Lonetree Blvd Ste 300',
#      'city': 95765.0,
#      'state': 'CA',
#      'lat': 38.79647,
#      'lng': -121.29275}]},
#   {'tap': 'Allagash James Bean',
#    'brewery': 'Allagash Brewery',
#    'locations': [{'location': '2M - Yardhouse (Roseville/Roseville)',
#      'address': '1166 Roseville Pkwy',
#      'city': 95678.0,
#      'state': 'CA',
#      'lat': 38.770788,
#      'lng': -121.270995}]},
#   {'tap': 'Altamont Beer Works Maui Waui',
#    'brewery': 'Altamont Beer Works',
#    'locations': [{'location': '2M - Yardhouse (Roseville/Roseville)',
#      'address': '1166 Roseville Pkwy',
#      'city': 95678.0,
#      'state': 'CA',
#      'lat': 38.770788,
#      'lng': -121.270995},
#     {'location': 'Anatolian Table Restaurant (Rocklin/Lonetree)',
#      'address': '6504 Lonetree Blvd',
#      'city': 95765.0,
#      'state': 'CA',
#      'lat': 38.80318,
#      'lng': -121.29413999999998},
#     {'location': 'Famous Burger (Rancho Cordova/Zinfandel)',
#      'address': '3101 Zinfandel Drive 132',
#      'city': 95670.0,
#      'state': 'CA',
#      'lat': 38.58748,
#      'lng': -121.28593000000001},
#     {'location': 'The Jungle Bird (Sacramento/J)',
#      'address': '2516 J Street',
#      'city': 95816.0,
#      'state': 'CA',
#      'lat': 38.574670000000005,
#      'lng': -121.47256999999999},
#     {'location': 'The Murieta Inn & Spa (Rancho Murieta/Murieta Dr)',
#      'address': '7337 Murieta Dr',
#      'city': 95683.0,
#      'state': 'CA',
#      'lat': 38.491644,
#      'lng': -121.099654},
#     {'location': 'Tres Hermanas Inc (Sacramento/K)',
#      'address': '2416 K St',
#      'city': 95816.0,
#      'state': 'CA',
#      'lat': 38.57382,
#      'lng': -121.47448999999999}]},
#   {'tap': 'Anderson Valley Hop Hyzer',
#    'brewery': 'Anderson Valley',
#    'locations': [{'location': '2M - Yardhouse (Roseville/Roseville)',
#      'address': '1166 Roseville Pkwy',
#      'city': 95678.0,
#      'state': 'CA',
#      'lat': 38.770788,
#      'lng': -121.270995}]},
#   {'tap': 'Ayinger Bavarian Pilsner',
#    'brewery': 'Ayinger Brewery',
#    'locations': [{'location': '2M - Yardhouse (Roseville/Roseville)',
#      'address': '1166 Roseville Pkwy',
#      'city': 95678.0,
#      'state': 'CA',
#      'lat': 38.770788,
#      'lng': -121.270995},
#     {'location': '2M - Yardhouse (Sacramento/K)',
#      'address': '405 K St Ste 100',
#      'city': 95814.0,
#      'state': 'CA',
#      'lat': 38.581758,
#      'lng': -121.50178600000001}]},
#   {'tap': 'Ayinger Oktoberfest',
#    'brewery': 'Ayinger Brewery',
#    'locations': [{'location': '2M - Yardhouse (Roseville/Roseville)',
#      'address': '1166 Roseville Pkwy',
#      'city': 95678.0,
#      'state': 'CA',
#      'lat': 38.770788,
#      'lng': -121.270995}]},
#   {'tap': 'Baptist Wit',
#    'brewery': 'Craft',
#    'locations': [{'location': '2M - Yardhouse (Roseville/Roseville)',
#      'address': '1166 Roseville Pkwy',
#      'city': 95678.0,
#      'state': 'CA',
#      'lat': 38.770788,
#      'lng': -121.270995},
#     {'location': '2M - Yardhouse (Sacramento/K)',
#      'address': '405 K St Ste 100',
#      'city': 95814.0,
#      'state': 'CA',
#      'lat': 38.581758,
#      'lng': -121.50178600000001}]},
#   {'tap': 'Berryessa IPA',
#    'brewery': 'Berryessa Brewing Co',
#    'locations': [{'location': '2M - Yardhouse (Roseville/Roseville)',
#      'address': '1166 Roseville Pkwy',
#      'city': 95678.0,
#      'state': 'CA',
#      'lat': 38.770788,
#      'lng': -121.270995},
#     {'location': 'Bistro 33 (Davis/F)',
#      'address': '226 F St',
#      'city': 95616.0,
#      'state': 'CA',
#      'lat': 38.544470000000004,
#      'lng': -121.73987},
#     {'location': 'Broderick (Sacramento/L)',
#      'address': '1820 L St.',
#      'city': 95811.0,
#      'state': 'CA',
#      'lat': 38.574967,
#      'lng': -121.48279099999999},
#     {'location': 'Davis Golf Course (Davis/Fairway)',
#      'address': '24439 Fairway Dr',
#      'city': 95616.0,
#      'state': 'CA',
#      'lat': 38.58374,
#      'lng': -121.77212},
#     {'location': 'Putah Creek Cafe (Winters/Main)',
#      'address': '1 Main St',
#      'city': 95694.0,
#      'state': 'CA',
#      'lat': 38.522059999999996,
#      'lng': -121.96903999999999},
#     {'location': 'Round Table (Winters/E Grant)',
#      'address': '196 E Grant Ave',
#      'city': 95694.0,
#      'state': 'CA',
#      'lat': 38.526720000000005,
#      'lng': -121.96488000000001}]},
#   {'tap': 'Brouweirj Petrus Sour Saison De Pale',
#    'brewery': 'Global Beer Network',
#    'locations': [{'location': '2M - Yardhouse (Roseville/Roseville)',
#      'address': '1166 Roseville Pkwy',
#      'city': 95678.0,
#      'state': 'CA',
#      'lat': 38.770788,
#      'lng': -121.270995}]},
#   {'tap': 'Brouwerij Bavik Pilsner',
#    'brewery': 'Global Beer Network',
#    'locations': [{'location': '2M - Yardhouse (Roseville/Roseville)',
#      'address': '1166 Roseville Pkwy',
#      'city': 95678.0,
#      'state': 'CA',
#      'lat': 38.770788,
#      'lng': -121.270995},
#     {'location': 'La Crosta Pizza Bar (West Sacramento/3rd)',
#      'address': '330 3Rd St',
#      'city': 95605.0,
#      'state': 'CA',
#      'lat': 38.587559999999996,
#      'lng': -121.51042}]},
#   ...]}
